# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.2 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 822.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.8 MB 1.7 MB/s eta 0:00:10
#     --------------------------------------- 0.3/15.8 MB 2.1 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/15.8 MB 2.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/15.8 MB 2.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/15.8 MB 2.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/15.8 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.9/15.8 MB 2.6 MB/s eta 0:00:06
# ...

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50,size=(10))

# %%
random_int_array
# Out:
# array([23, 19, 16, 27, 43, 25,  2, 30,  3,  3])

# %%
np.ndim(random_int_array)
# Out:
# 1

# %%
random_int_array.shap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 random_int_array.shap
#
# AttributeError: 'numpy.ndarray' object has no attribute 'shap'

# %%
random_int_array.shape
# Out:
# (10,)

# %%
newarr = np.random.randint(1, 100, size=(2, 5))

# %%
newarr
# Out:
# array([[50, 81,  4,  9, 83],
#        [14, 24, 44, 15, 75]])

# %%
newarr.shape
# Out:
# (2, 5)

# %%
np.ndim(newarr)
# Out:
# 2
